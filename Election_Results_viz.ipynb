# %% [markdown]
# <a href="https://colab.research.google.com/github/MDAnsaar25/Election-Analysis/blob/main/Election_Results_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/content/drive/MyDrive/Data Sets/results_2024_winners.csv')

# %%
df
# Out:
#                  State  PC No          PC Name  \
# 0       Andhra Pradesh      7  Amalapuram (SC)
# 1       Andhra Pradesh      5       Anakapalle
# 2       Andhra Pradesh     19       Ananthapur
# 3       Andhra Pradesh      1       Araku (ST)
# 4       Andhra Pradesh     15     Bapatla (SC)
# ..                 ...    ...              ...
# 538  Jammu and Kashmir      1        BARAMULLA
# 539  Jammu and Kashmir      5            JAMMU
# 540  Jammu and Kashmir      2         SRINAGAR
# 541  Jammu and Kashmir      4         UDHAMPUR
# 542             Ladakh      1           Ladakh
#
#                     Winning Candidate                          Winning Party  \
# 0               G M HARISH (BALAYOGI)                           Telugu Desam
# 1                          C.M.RAMESH                 Bharatiya Janata Party
# 2    AMBICA G LAKSHMINARAYANA VALMIKI                           Telugu Desam
# 3                  GUMMA THANUJA RANI  Yuvajana Sramika Rythu Congress Party
# ...

# %%
df.head(10)
# Out:
#             State  PC No          PC Name                 Winning Candidate  \
# 0  Andhra Pradesh      7  Amalapuram (SC)             G M HARISH (BALAYOGI)
# 1  Andhra Pradesh      5       Anakapalle                        C.M.RAMESH
# 2  Andhra Pradesh     19       Ananthapur  AMBICA G LAKSHMINARAYANA VALMIKI
# 3  Andhra Pradesh      1       Araku (ST)                GUMMA THANUJA RANI
# 4  Andhra Pradesh     15     Bapatla (SC)            KRISHNA PRASAD TENNETI
# 5  Andhra Pradesh     25     Chittoor(SC)            DAGGUMALLA PRASADA RAO
# 6  Andhra Pradesh     10            Eluru                PUTTA MAHESH KUMAR
# 7  Andhra Pradesh     13           Guntur       DR CHANDRA SEKHAR PEMMASANI
# 8  Andhra Pradesh     20         Hindupur                 B K PARTHASARATHI
# 9  Andhra Pradesh     21           Kadapa               Y. S. AVINASH REDDY
#
#                            Winning Party  \
# 0                           Telugu Desam
# 1                 Bharatiya Janata Party
# ...

# %%
df.tail(10)
# Out:
#                  State  PC No           PC Name          Winning Candidate  \
# 533       NCT OF Delhi      7       South Delhi       RAMVIR SINGH BIDHURI
# 534       NCT OF Delhi      6        West Delhi         KAMALJEET SEHRAWAT
# 535        Lakshadweep      1       Lakshadweep  MUHAMMED HAMDULLAH SAYEED
# 536         Puducherry      1        PUDUCHERRY            VE VAITHILINGAM
# 537  Jammu and Kashmir      3  ANANTNAG-RAJOURI           MIAN ALTAF AHMAD
# 538  Jammu and Kashmir      1         BARAMULLA        ABDUL RASHID SHEIKH
# 539  Jammu and Kashmir      5             JAMMU              JUGAL KISHORE
# 540  Jammu and Kashmir      2          SRINAGAR    AGA SYED RUHULLAH MEHDI
# 541  Jammu and Kashmir      4          UDHAMPUR          DR JITENDRA SINGH
# 542             Ladakh      1            Ladakh             MOHMAD HANEEFA
#
#                            Winning Party    Runner-up Canddiate  \
# 533               Bharatiya Janata Party               SAHI RAM
# ...

# %%
df_TN = df[df['State']== 'Tamil Nadu' ]

# %%
df_TN
# Out:
#           State  PC No          PC Name  \
# 314  Tamil Nadu      7        ARAKKONAM
# 315  Tamil Nadu     12            ARANI
# 316  Tamil Nadu      4  CHENNAI CENTRAL
# 317  Tamil Nadu      2    CHENNAI NORTH
# 318  Tamil Nadu      3    CHENNAI SOUTH
# 319  Tamil Nadu     27      CHIDAMBARAM
# 320  Tamil Nadu     20       COIMBATORE
# 321  Tamil Nadu     26        CUDDALORE
# 322  Tamil Nadu     10       DHARMAPURI
# 323  Tamil Nadu     22         DINDIGUL
# 324  Tamil Nadu     17            ERODE
# 325  Tamil Nadu     14     KALLAKURICHI
# 326  Tamil Nadu      6     KANCHEEPURAM
# 327  Tamil Nadu     39    KANNIYAKUMARI
# 328  Tamil Nadu     23            KARUR
# 329  Tamil Nadu      9      KRISHNAGIRI
# 330  Tamil Nadu     32          MADURAI
# 331  Tamil Nadu     28   MAYILADUTHURAI
# 332  Tamil Nadu     29     NAGAPATTINAM
# 333  Tamil Nadu     16         NAMAKKAL
# 334  Tamil Nadu     19         NILGIRIS
# 335  Tamil Nadu     25       PERAMBALUR
# ...

# %%
# @title Distribution of Winning Parties

import matplotlib.pyplot as plt

df_TN['Winning Party'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.ylabel('')
_ = plt.title('Distribution of Winning Parties')
